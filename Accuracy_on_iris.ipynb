# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
data = pd.read_excel(r"C:\Users\mahak\Practical_sklearns\iris-train.xlsx")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width           class
# 0           7.2          3.6           6.1          2.5  Iris-virginica
# 1           6.3          3.3           6.0          2.5  Iris-virginica
# 2           6.7          3.3           5.7          2.5  Iris-virginica
# 3           6.3          3.4           5.6          2.4  Iris-virginica
# 4           6.7          3.1           5.6          2.4  Iris-virginica

# %%
x = data.iloc[:,:-1]

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             7.2          3.6           6.1          2.5
# 1             6.3          3.3           6.0          2.5
# 2             6.7          3.3           5.7          2.5
# 3             6.3          3.4           5.6          2.4
# 4             6.7          3.1           5.6          2.4
# ..            ...          ...           ...          ...
# 111           4.9          3.1           1.5          0.1
# 112           4.9          3.1           1.5          0.1
# 113           4.9          3.1           1.5          0.1
# 114           4.8          3.0           1.4          0.1
# 115           4.3          3.0           1.1          0.1
#
# [116 rows x 4 columns]

# %%
y = data.iloc[:,-1]

# %%
y
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
#             ...
# 111       Iris-setosa
# 112       Iris-setosa
# 113       Iris-setosa
# 114       Iris-setosa
# 115       Iris-setosa
# Name: class, Length: 116, dtype: object

# %%
model = RandomForestClassifier()

# %%
model = DecisionTreeClassifier()

# %%
model = GaussianNB()

# %%
x.values
# Out:
# array([[7.2, 3.6, 6.1, 2.5],
#        [6.3, 3.3, 6. , 2.5],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.7, 3.1, 5.6, 2.4],
#        [5.8, 2.8, 5.1, 2.4],
#        [7.7, 2.6, 6.9, 2.3],
#        [7.7, 3. , 6.1, 2.3],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.2, 3.4, 5.4, 2.3],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.7, 3. , 5.2, 2.3],
#        [6.9, 3.1, 5.1, 2.3],
#        [7.7, 3.8, 6.7, 2.2],
#        [6.5, 3. , 5.8, 2.2],
#        [6.4, 2.8, 5.6, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [7.1, 3. , 5.9, 2.1],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.4, 2.8, 5.6, 2.1],
#        [6.8, 3. , 5.5, 2.1],
#        [6.9, 3.1, 5.4, 2.1],
#        [7.7, 2.8, 6.7, 2. ],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.5, 3. , 5.2, 2. ],
#        [6.5, 3.2, 5.1, 2. ],
#        [5.7, 2.5, 5. , 2. ],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.4, 2.8, 6.1, 1.9],
#        [6.4, 2.7, 5.3, 1.9],
#        [5.8, 2.7, 5.1, 1.9],
# ...

# %%
y.values
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
model.fit(x.values, y.values)
# Out:
# GaussianNB()

# %%
predictions = model.predict([[7.2,	3.6,	6.1,	2.5]])

# %%
predictions
# Out:
# array(['Iris-virginica'], dtype='<U15')

# %%
datatest = pd.read_excel(r"C:\Users\mahak\Practical_sklearns\iris-test.xlsx")

# %%
import os
print(os.listdir(r"C:\Users\mahak\OneDrive\Documents\Practical_sklearn"))
# Out:
# ['.ipynb_checkpoints', 'iris-test.xlsx', 'iris-train.xlsx', 'Quick_training_on_iris.ipynb']

# %%
x_test = datatest.iloc[:, :-1]

# %%
predictions = model.predict(x_test.values)

# %%
predictions
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa'], dtype='<U15')

# %%
y_test = datatest.iloc[:, -1]

# %%
y_test
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
# 5      Iris-virginica
# 6      Iris-virginica
# 7     Iris-versicolor
# 8      Iris-virginica
# 9      Iris-virginica
# 10    Iris-versicolor
# 11     Iris-virginica
# 12     Iris-virginica
# 13    Iris-versicolor
# 14    Iris-versicolor
# 15    Iris-versicolor
# 16     Iris-virginica
# 17     Iris-virginica
# 18    Iris-versicolor
# 19    Iris-versicolor
# 20    Iris-versicolor
# 21    Iris-versicolor
# 22    Iris-versicolor
# 23    Iris-versicolor
# 24     Iris-virginica
# 25    Iris-versicolor
# 26    Iris-versicolor
# 27    Iris-versicolor
# 28    Iris-versicolor
# 29    Iris-versicolor
# 30    Iris-versicolor
# 31    Iris-versicolor
# 32        Iris-setosa
# 33        Iris-setosa
# 34        Iris-setosa
# 35        Iris-setosa
# 36        Iris-setosa
# Name: class, dtype: object

# %%
actual = y_test.values

# %%
actual
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa'], dtype=object)

# %%
count = 0
for i in range(0, len(actual)):
    if actual[i] == predictions[i]:
        count = count+1
print((count* 100)/len(actual))
# Out:
# 83.78378378378379

# %%
y_test = datatest.iloc[:, -1]

# %%
y_test
# Out:
# 0      Iris-virginica
# 1      Iris-virginica
# 2      Iris-virginica
# 3      Iris-virginica
# 4      Iris-virginica
# 5      Iris-virginica
# 6      Iris-virginica
# 7     Iris-versicolor
# 8      Iris-virginica
# 9      Iris-virginica
# 10    Iris-versicolor
# 11     Iris-virginica
# 12     Iris-virginica
# 13    Iris-versicolor
# 14    Iris-versicolor
# 15    Iris-versicolor
# 16     Iris-virginica
# 17     Iris-virginica
# 18    Iris-versicolor
# 19    Iris-versicolor
# 20    Iris-versicolor
# 21    Iris-versicolor
# 22    Iris-versicolor
# 23    Iris-versicolor
# 24     Iris-virginica
# 25    Iris-versicolor
# 26    Iris-versicolor
# 27    Iris-versicolor
# 28    Iris-versicolor
# 29    Iris-versicolor
# 30    Iris-versicolor
# 31    Iris-versicolor
# 32        Iris-setosa
# 33        Iris-setosa
# 34        Iris-setosa
# 35        Iris-setosa
# 36        Iris-setosa
# Name: class, dtype: object
